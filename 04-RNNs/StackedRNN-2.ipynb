# %% [markdown]
# <a href="https://colab.research.google.com/github/Amruth-U-tech/DL-Journey/blob/main/04-RNNs/StackedRNN-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **RNN arctecture on aplle stack market data set**

# %%
#the apple stock market data set is in yahoo finance website so we install that dependiencie here
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.0.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.14.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import yfinance as yf
import numpy as np
import pandas as pd #for data handling or to read
import matplotlib.pyplot as plt #to print any 2D instance
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN, Bidirectional, Input  #we got two RNNs here
from tensorflow.keras.optimizers import Adam

# %%
df = yf.download("AAPL",period="5y",auto_adjust=True)[["Close"]]  #we are dowloding "AAPL" which mean aplle stock market data of period 5years

#with the target variable as close which means there is a feature in that data known as close which shos the closing price of the stock and that Y
df.head(10)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close
# Ticker            AAPL
# Date
# 2021-03-17  121.515678
# 2021-03-18  117.395668
# 2021-03-19  116.869720
# 2021-03-22  120.181305
# 2021-03-23  119.353409
# 2021-03-24  116.967117
# 2021-03-25  117.454132
# 2021-03-26  118.058014
# 2021-03-29  118.233315
# 2021-03-30  116.782059

# %%
df.shape
# Out:
# (1256, 1)

# %% [markdown]
# **preprocessing the data**

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df)
scaled_data
# Out:
# array([[2.79863344e-02],
#        [3.62781055e-03],
#        [5.18277982e-04],
#        ...,
#        [7.88326973e-01],
#        [8.04290115e-01],
#        [8.11798605e-01]])

# %%
from pandas.core.window.rolling import Window
#now because this is Sequential data we make our x and Y in such a way itself
#such that some input X1 will give some input Y1 then that Y1 is included with X1 by removing previous data of X1 hence X2=X1-X1[0]+Y1 we get Y2

def create_sequence(data,window=30):
  X,Y = [],[]
  for i in range(window,len(data)):
    X.append(data[i-window:i])
    Y.append(data[i])
  return np.array(X),np.array(Y)

Window_size = 30
x,y = create_sequence(scaled_data,window=Window_size)

# %%
x.shape
# Out:
# (1226, 30, 1)

# %%
y.shape
# Out:
# (1226, 1)

# %%
#tain and test split
split = int(len(x)*0.8)
x_train,x_test = x[:split],x[split:]
y_train,y_test = y[:split],y[split:]
#note that u cannot split it as we did for other tabular data or anything cause these are squential

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (980, 30, 1) (246, 30, 1) (980, 1) (246, 1)

# %%
#remember from the RNN structure and match the beloow data as a sequense data
print(x[0])
print(y[0])   #this y_train[0] should be equal to x[30]th first value which is on 30th day

#what it means is from the sequense of 0 to 29th day data we predict the target value and shall get y[0] which is the price of 30th day stock
#check below
# Out:
# [[0.02798633]
#  [0.00362781]
#  [0.00051828]
#  [0.02009719]
#  [0.01520246]
#  [0.00109411]
#  [0.00397346]
#  [0.00754376]
#  [0.00858018]
#  [0.        ]
#  [0.01295668]
#  [0.01785145]
#  [0.0345511 ]
#  [0.03633625]
#  [0.04606806]
#  [0.06023396]
#  [0.07543656]
#  [0.06530136]
#  [0.08367091]
#  [0.0698507 ]
#  [0.08407416]
#  [0.08211616]
#  [0.08603216]
#  [0.07606986]
#  [0.07831582]
#  [0.06933242]
#  [0.08303779]
#  [0.08534112]
#  [0.08344077]
#  [0.07877627]]
# [0.07820061]

# %%
print(x[30])  #checking on 30th day stock price
# Out:
# [[0.07820061]
#  [0.06656827]
#  [0.07278761]
#  [0.04578014]
#  [0.04721982]
#  [0.05666366]
#  [0.06064371]
#  [0.04126242]
#  [0.03584021]
#  [0.01772786]
#  [0.03041796]
#  [0.04472333]
#  [0.03791679]
#  [0.02972584]
#  [0.0288029 ]
#  [0.04391583]
#  [0.03307141]
#  [0.04270448]
#  [0.04155087]
#  [0.04126242]
#  [0.03220626]
#  [0.02834146]
#  [0.02643795]
#  [0.03093718]
#  [0.02216958]
#  [0.03572487]
#  [0.03578261]
#  [0.0406279 ]
#  [0.04287756]
#  [0.03699382]]

# %%
plt.figure(figsize=(10,4))
plt.plot(df["Close"])
plt.title("apple stock market data")
plt.xlabel("time")
plt.ylabel("closing price")
# Out:
# Text(0, 0.5, 'closing price')

# %%
plt.figure(figsize=(8,4))
plt.plot(x[0])
plt.title("one input sequence for 30 days time")
plt.xlabel("time")
plt.ylabel("closing price")
plt.show()

# %%
i = 30
Window_size=30
plt.figure(figsize=(12,4))

#full series plot
plt.plot(df["Close"].values,color="lightgray",label="full series")

#ploting sliding window on the sma e plot (same as mtlab if u dont create another figure instance it will be ploted ont he same graph)
plt.plot(range(i-Window_size,i),df["Close"].values[i-Window_size:i],color="blue",linewidth=2,label="input window x")

plt.scatter(i,df["Close"].values[i],color="red",s=100,label="Target Y")
plt.title("sliding window visualisation window_size=30")
plt.xlabel("time")
plt.ylabel("closing price")
plt.legend()
plt.show()

# %%
#now building an simple rnn

model_rnn = Sequential([SimpleRNN(50,return_sequences=False,input_shape=(Window_size,1)),Dense(1)])
model_rnn.compile(optimizer="adam",loss="mse")
model_rnn.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 50)             │         2,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,651 (10.36 KB)
#  Trainable params: 2,651 (10.36 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_rnn = model_rnn.fit(x_train,y_train,epochs=10,batch_size=32,validation_data=(x_test,y_test))
# Out:
# Epoch 1/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.0493 - val_loss: 0.0080
# Epoch 2/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 3/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.1412e-04 - val_loss: 0.0032
# Epoch 4/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.3735e-04 - val_loss: 0.0023
# Epoch 5/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.7450e-04 - val_loss: 0.0026
# Epoch 6/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.2145e-04 - val_loss: 0.0023
# Epoch 7/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.9630e-04 - val_loss: 0.0029
# Epoch 8/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.7910e-04 - val_loss: 0.0019
# Epoch 9/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.4314e-04 - val_loss: 0.0019
# Epoch 10/10
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.3846e-04 - val_loss: 0.0019

# %%
#model prediction
prediction = model_rnn.predict(x_test)
prediction=scaler.inverse_transform(prediction)
y_test1 = scaler.inverse_transform(y_test)

for i in range(len(prediction)):
  print(f"prdeiction: {prediction[i][0]:.2f}, actual:{y_test1[i][0]:.2f}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# prdeiction: 217.99, actual:222.78
# prdeiction: 221.49, actual:220.57
# prdeiction: 223.42, actual:222.88
# prdeiction: 223.85, actual:216.95
# prdeiction: 223.06, actual:221.17
# prdeiction: 222.84, actual:222.22
# prdeiction: 223.31, actual:222.92
# prdeiction: 224.77, actual:202.31
# prdeiction: 218.35, actual:187.56
# prdeiction: 204.81, actual:180.67
# prdeiction: 191.64, actual:171.67
# prdeiction: 182.95, actual:197.99
# prdeiction: 178.47, actual:189.59
# prdeiction: 193.89, actual:197.29
# prdeiction: 192.26, actual:201.64
# prdeiction: 196.66, actual:201.26
# prdeiction: 205.41, actual:193.43
# prdeiction: 193.09, actual:196.13
# prdeiction: 199.00, actual:192.32
# prdeiction: 196.25, actual:198.87
# prdeiction: 200.01, actual:203.71
# prdeiction: 203.22, actual:207.47
# prdeiction: 209.80, actual:208.37
# prdeiction: 211.73, actual:209.23
# prdeiction: 213.59, actual:210.29
# prdeiction: 211.09, actual:211.58
# prdeiction: 207.45, actual:212.39
# prdeiction: 207.76, actual:204.46
# prdeiction: 211.06, actual:198.03
# prdeiction: 206.20, actual:197.65
# prdeiction: 201.83, actual:195.40
# prdeiction: 201.27, actual:196.63
# prdeiction: 195.96, actual:197.67
# prdeiction: 199.72, actual:210.15
# prdeiction: 199.94, actual:212.28
# prdeiction: 208.32, actual:211.69
# prdeiction: 209.79, actual:210.81
# prdeiction: 212.51, actual:210.62
# prdeiction: 211.60, actual:208.15
# prdeiction: 211.68, actual:206.23
# prdeiction: 209.03, actual:201.48
# prdeiction: 207.99, actual:200.75
# prdeiction: 205.20, actual:194.68
# prdeiction: 204.64, actual:199.60
# prdeiction: 199.62, actual:199.81
# prdeiction: 200.34, actual:199.34
# prdeiction: 199.39, actual:200.24
# prdeiction: 198.99, actual:201.09
# prdeiction: 201.17, actual:202.65
# prdeiction: 199.33, actual:202.20
# prdeiction: 202.37, actual:200.02
# prdeiction: 203.85, actual:203.30
# prdeiction: 203.57, actual:200.84
# prdeiction: 205.32, actual:202.06
# prdeiction: 202.67, actual:198.18
# prdeiction: 204.20, actual:198.60
# prdeiction: 201.63, actual:195.85
# prdeiction: 200.17, actual:197.82
# prdeiction: 198.78, actual:195.05
# prdeiction: 197.41, actual:195.98
# prdeiction: 196.76, actual:200.39
# prdeiction: 197.73, actual:200.89
# prdeiction: 201.09, actual:199.69
# prdeiction: 200.70, actual:200.95
# prdeiction: 200.61, actual:200.39
# prdeiction: 203.14, actual:200.47
# prdeiction: 201.28, actual:204.55
# prdeiction: 203.18, actual:207.19
# prdeiction: 205.68, actual:211.80
# prdeiction: 209.81, actual:212.90
# prdeiction: 212.91, actual:209.31
# prdeiction: 213.71, actual:209.37
# prdeiction: 209.94, actual:210.50
# prdeiction: 211.47, actual:211.77
# prdeiction: 211.28, actual:210.52
# prdeiction: 211.92, actual:207.99
# prdeiction: 210.78, actual:208.48
# prdeiction: 210.52, actual:209.52
# prdeiction: 210.08, actual:209.38
# prdeiction: 210.22, actual:210.54
# prdeiction: 209.28, actual:211.84
# prdeiction: 211.27, actual:213.75
# prdeiction: 212.34, actual:213.50
# prdeiction: 213.74, actual:213.11
# prdeiction: 213.16, actual:213.23
# prdeiction: 214.32, actual:213.40
# prdeiction: 215.27, actual:210.63
# prdeiction: 213.96, actual:208.42
# prdeiction: 211.61, actual:206.94
# prdeiction: 209.65, actual:201.77
# prdeiction: 208.15, actual:202.73
# prdeiction: 204.73, actual:202.30
# prdeiction: 204.09, actual:212.60
# prdeiction: 205.56, actual:219.36
# prdeiction: 212.51, actual:228.65
# prdeiction: 220.38, actual:226.75
# prdeiction: 224.68, actual:229.21
# prdeiction: 227.59, actual:232.89
# prdeiction: 229.03, actual:232.34
# prdeiction: 233.20, actual:231.15
# prdeiction: 230.90, actual:230.45
# prdeiction: 232.79, actual:230.12
# prdeiction: 232.59, actual:225.58
# prdeiction: 230.41, actual:224.47
# prdeiction: 227.05, actual:227.33
# prdeiction: 225.05, actual:226.73
# prdeiction: 226.44, actual:228.87
# prdeiction: 224.99, actual:230.05
# prdeiction: 226.83, actual:232.12
# prdeiction: 227.57, actual:231.70
# prdeiction: 229.74, actual:229.28
# prdeiction: 230.74, actual:238.02
# prdeiction: 230.88, actual:239.32
# prdeiction: 235.80, actual:239.23
# prdeiction: 237.65, actual:237.43
# prdeiction: 237.22, actual:233.90
# prdeiction: 238.04, actual:226.36
# prdeiction: 231.52, actual:229.59
# prdeiction: 229.52, actual:233.62
# prdeiction: 229.93, actual:236.25
# prdeiction: 232.77, actual:237.70
# prdeiction: 233.86, actual:238.54
# prdeiction: 236.99, actual:237.43
# prdeiction: 236.22, actual:245.03
# prdeiction: 237.24, actual:255.59
# prdeiction: 244.07, actual:253.95
# prdeiction: 249.94, actual:251.83
# prdeiction: 249.45, actual:256.38
# prdeiction: 251.14, actual:254.97
# prdeiction: 253.55, actual:253.95
# prdeiction: 251.10, actual:254.15
# prdeiction: 251.88, actual:254.96
# prdeiction: 251.87, actual:256.64
# prdeiction: 251.42, actual:257.53
# prdeiction: 252.47, actual:256.20
# prdeiction: 252.01, actual:255.99
# prdeiction: 251.28, actual:257.57
# prdeiction: 252.89, actual:253.56
# prdeiction: 251.94, actual:244.80
# prdeiction: 247.24, actual:247.19
# prdeiction: 242.77, actual:247.30
# prdeiction: 244.92, actual:248.87
# prdeiction: 244.13, actual:246.98
# prdeiction: 244.16, actual:251.81
# prdeiction: 245.46, actual:261.74
# prdeiction: 249.07, actual:262.27
# prdeiction: 256.21, actual:257.96
# prdeiction: 255.01, actual:259.09
# prdeiction: 254.33, actual:262.32
# prdeiction: 257.04, actual:268.30
# prdeiction: 259.04, actual:268.49
# prdeiction: 262.04, actual:269.19
# prdeiction: 262.59, actual:270.88
# prdeiction: 264.27, actual:269.86
# prdeiction: 265.69, actual:268.54
# prdeiction: 263.11, actual:269.53
# prdeiction: 262.17, actual:269.63
# prdeiction: 263.15, actual:269.26
# prdeiction: 263.36, actual:267.96
# prdeiction: 262.53, actual:269.18
# prdeiction: 260.77, actual:274.99
# prdeiction: 263.05, actual:273.21
# prdeiction: 266.37, actual:272.69
# prdeiction: 265.35, actual:272.16
# prdeiction: 264.48, actual:267.21
# prdeiction: 264.03, actual:267.19
# prdeiction: 260.75, actual:268.31
# prdeiction: 261.95, actual:266.00
# prdeiction: 260.78, actual:271.24
# prdeiction: 260.46, actual:275.66
# prdeiction: 264.89, actual:276.71
# prdeiction: 266.93, actual:277.29
# prdeiction: 267.37, actual:278.59
# prdeiction: 269.70, actual:282.84
# prdeiction: 270.91, actual:285.92
# prdeiction: 273.95, actual:283.88
# prdeiction: 275.17, actual:280.44
# prdeiction: 273.95, actual:278.52
# prdeiction: 272.46, actual:277.63
# prdeiction: 270.84, actual:276.92
# prdeiction: 269.32, actual:278.52
# prdeiction: 268.48, actual:277.77
# prdeiction: 269.38, actual:278.02
# prdeiction: 269.05, actual:273.85
# prdeiction: 267.87, actual:274.35
# prdeiction: 266.05, actual:271.59
# prdeiction: 265.38, actual:271.94
# prdeiction: 264.65, actual:273.41
# prdeiction: 264.29, actual:270.72
# prdeiction: 264.92, actual:272.11
# prdeiction: 262.86, actual:273.55
# prdeiction: 265.12, actual:273.14
# prdeiction: 265.74, actual:273.50
# prdeiction: 265.02, actual:272.82
# prdeiction: 266.22, actual:271.61
# prdeiction: 265.12, actual:270.76
# prdeiction: 264.69, actual:267.01
# prdeiction: 263.52, actual:262.11
# prdeiction: 260.27, actual:260.09
# prdeiction: 257.19, actual:258.80
# prdeiction: 255.55, actual:259.13
# prdeiction: 253.85, actual:260.01
# prdeiction: 253.81, actual:260.81
# prdeiction: 254.58, actual:259.72
# prdeiction: 255.11, actual:257.97
# prdeiction: 254.39, actual:255.29
# prdeiction: 253.07, actual:246.47
# prdeiction: 249.92, actual:247.42
# prdeiction: 245.19, actual:248.12
# prdeiction: 245.49, actual:247.81
# prdeiction: 245.42, actual:255.17
# prdeiction: 245.56, actual:258.03
# prdeiction: 252.26, actual:256.20
# prdeiction: 252.65, actual:258.04
# prdeiction: 252.73, actual:259.24
# prdeiction: 255.10, actual:269.76
# prdeiction: 256.65, actual:269.23
# prdeiction: 262.93, actual:276.23
# prdeiction: 265.34, actual:275.65
# prdeiction: 268.44, actual:277.86
# prdeiction: 270.67, actual:274.62
# prdeiction: 269.10, actual:273.68
# prdeiction: 269.53, actual:275.50
# prdeiction: 266.55, actual:261.73
# prdeiction: 266.28, actual:255.78
# prdeiction: 256.37, actual:263.88
# prdeiction: 253.86, actual:264.35
# prdeiction: 257.95, actual:260.58
# prdeiction: 254.67, actual:264.58
# prdeiction: 256.03, actual:266.18
# prdeiction: 258.28, actual:272.14
# prdeiction: 259.11, actual:274.23
# prdeiction: 263.56, actual:272.95
# prdeiction: 266.13, actual:264.18
# prdeiction: 263.30, actual:264.72
# prdeiction: 261.50, actual:263.75
# prdeiction: 259.59, actual:262.52
# prdeiction: 258.39, actual:260.29
# prdeiction: 255.79, actual:257.46
# prdeiction: 256.95, actual:259.88
# prdeiction: 253.61, actual:260.83
# prdeiction: 254.56, actual:260.81
# prdeiction: 254.52, actual:255.76
# prdeiction: 254.09, actual:250.12
# prdeiction: 251.85, actual:252.82
# prdeiction: 248.23, actual:254.09

# %%
#u can plot the prdictited values and actual values to see graphically how closely the model is folowing

#NOw lets build stacled rnn
model_deep_rnn = Sequential([SimpleRNN(50, return_sequences=True, input_shape=(Window_size,1)),SimpleRNN(50),Dense(1)])
model_deep_rnn.compile(optimizer="adam",loss="mse") #u need return_sequense true so that the next layer of rnn gets some input or u will get error
model_deep_rnn.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_8 (SimpleRNN)        │ (None, 30, 50)         │         2,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_9 (SimpleRNN)        │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7,701 (30.08 KB)
#  Trainable params: 7,701 (30.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model_bid = Sequential([Bidirectional(SimpleRNN(50),input_shape=(Window_size,1)),Dense(1)])
model_bid.compile(optimizer="adam",loss="mse")
model_bid.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 100)            │         5,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,301 (20.71 KB)
#  Trainable params: 5,301 (20.71 KB)
#  Non-trainable params: 0 (0.00 B)
