# %% [markdown]
# <a href="https://colab.research.google.com/github/Amruth-U-tech/DL-Journey/blob/main/03-CNN/EnsembleCNN-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Enseble CNN model**
#
# for this u will have to create multiple CNN models and merge its results to send it to another model so that we have our answers much more confidently
#
# **Enseble model meaning**
#
# u will combine multiple output or prediction of diff models to get a combined much more enhanced output/prediction
#
# **few things to keep in mind in this program**
# 1.  this program does not have creation of cnn model, we directly jump to enseble concept
# 2.  assume ther is CNN1,CNN2,CNN3 model trained and tested
# 3.  input_shape = (128x128x1) and n_classes = 4 (no. of output clases)
# 4.  all libs are imported

# %%
for base_model in [CNN1,CNN2,CNN3]:
  base_model.trainable = False

stack_input = Input(shape=input_shape)
pred1 = CNN1(stack_input)
pred2 = CNN2(stack_input)
pred3 = CNN3(stack_input)

merged = Concatenate()([pred1,pred2,pred3]) #merging the output of all other cnn models eg:-cnn1=[0.1,0.9] cnn2=[0.3,0.7] merge=[0.1,0.9,0.3,0.7]
#this is known as meta_data
meta_input_dim = 3*n_classes

MLP_meta = Sequential(name="MLP_meta")
'''{
  create a meta_mlp model to train of the merged data cause it will learn which model to trust the most and how to know which is it actually belongs
  with output having same no. of neurons as the other models trained on the same data (n_classes)
}'''

stack_output = MLP_meta(merged) #this gives the merged predictions

#final stacked model is
stack_model = Model(inputs=stack_input,output=stack_output)

#then complie and train it to get much better prdictions with higher confindence
